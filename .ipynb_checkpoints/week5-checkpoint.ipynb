# %% [markdown]
# # Capstone Project:The Battle of Neighborhoods (Week 2)

# %% [markdown]
# ## Table of contents
# * [Background](#Background)
# * [Problem](#Probulem)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## 1) Background<a name="Background"></a>

# %% [markdown]
# I want to go back to my home town Toyota-city.
# However my wife was born in another area in Aichi, she is hesitating to go to Toyota-city.
# To overcome the situation I am planing to satisfy her dream by go back to Toyota-city.
# My wife's dream is to open a resturant.
# So showing the potential of Toyota-city for new resturant in this project.

# %% [markdown]
# ## 2) Problem<a name="Problem"></a>

# %% [markdown]
# The idea of this study is to show which part of Toyota-city is the best for new resturant by providing data about:
# potential customers from population derived from population distribution.
# competitors in the same regions.

# %% [markdown]
# ## 3) Data<a name="Data"></a>

# %% [markdown]
# For the study, population and resturant data in accordance with geographic information are needed.
# We can download population vs area name of Toyota-city from the URL below.
#
# https://www.city.toyota.aichi.jp/_res/projects/default_project/_page_/001/004/759/h29/01.xls
#
# Also we can download postcode list from the URL below.
#
# https://www.post.japanpost.jp/zipcode/dl/roman-zip.html
#
# Above two data can be linked by using area name and can be used to obtain geographic information(latitude & longitude) vs population.
# In paticular, I used below API to get geographic information from postcode.
#
# 'http://geoapi.heartrails.com/api/xml?method=searchByPostal&postal='
#
# Also we can get the resturant information by Foursquare API.
# This resulting in linked data among geographic information, population and competiters for new resturant.

# %% [markdown]
# ### Post code and area name of Toyota-city

# %%
import pandas as pd
import numpy as np
import urllib.request, urllib.error
import xml.etree.ElementTree
import requests

# %%
df = pd.read_csv("KEN_ALL_ROME.CSV", encoding='cp932')
df.head(10)
# Out:
#    Postcode PrefJP BoroughJP         AreaJP      Pref              Borough  \
# 0    600000    北海道   札幌市　中央区     以下に掲載がない場合  HOKKAIDO  SAPPORO SHI CHUO KU
# 1    640941    北海道   札幌市　中央区            旭ケ丘  HOKKAIDO  SAPPORO SHI CHUO KU
# 2    600041    北海道   札幌市　中央区            大通東  HOKKAIDO  SAPPORO SHI CHUO KU
# 3    600042    北海道   札幌市　中央区    大通西（１～１９丁目）  HOKKAIDO  SAPPORO SHI CHUO KU
# 4    640820    北海道   札幌市　中央区   大通西（２０～２８丁目）  HOKKAIDO  SAPPORO SHI CHUO KU
# 5    600031    北海道   札幌市　中央区           北一条東  HOKKAIDO  SAPPORO SHI CHUO KU
# 6    600001    北海道   札幌市　中央区   北一条西（１～１９丁目）  HOKKAIDO  SAPPORO SHI CHUO KU
# 7    640821    北海道   札幌市　中央区  北一条西（２０～２８丁目）  HOKKAIDO  SAPPORO SHI CHUO KU
# 8    600032    北海道   札幌市　中央区           北二条東  HOKKAIDO  SAPPORO SHI CHUO KU
# 9    600002    北海道   札幌市　中央区   北二条西（１～１９丁目）  HOKKAIDO  SAPPORO SHI CHUO KU
#
#                          Area
# 0        IKANIKEISAIGANAIBAAI
# 1                  ASAHIGAOKA
# 2                ODORIHIGASHI
# 3      ODORINISHI(1-19-CHOME)
# 4     ODORINISHI(20-28-CHOME)
# 5             KITA1-JOHIGASHI
# 6   KITA1-JONISHI(1-19-CHOME)
# 7  KITA1-JONISHI(20-28-CHOME)
# 8             KITA2-JOHIGASHI
# 9   KITA2-JONISHI(1-19-CHOME)

# %%
df = df[df['Borough'] == 'TOYOTA SHI'].reset_index()
df = df[['Postcode', 'AreaJP', 'Pref', 'Borough', 'Area']]
df.AreaJP.astype(str)
df.head()
# Out:
#    Postcode      AreaJP       Pref     Borough                  Area
# 0   4710000  以下に掲載がない場合  AICHI KEN  TOYOTA SHI  IKANIKEISAIGANAIBAAI
# 1   4710052         逢妻町  AICHI KEN  TOYOTA SHI             AIZUMACHO
# 2   4700335         青木町  AICHI KEN  TOYOTA SHI               AOKICHO
# 3   4710873         秋葉町  AICHI KEN  TOYOTA SHI              AKIBACHO
# 4   4710835          曙町  AICHI KEN  TOYOTA SHI            AKEBONOCHO

# %% [markdown]
# ### Area name and population of Toyota-city

# %%
df_pop = pd.read_csv("01.csv", encoding='cp932')
#df_pop.AreaJP.astype(str)
df_pop.head()
# Out:
#   AreaJP Population
# 0    逢妻町        684
# 1    秋葉町      1,906
# 2     曙町      1,055
# 3   朝日ケ丘      2,560
# 4    朝日町      3,759

# %%
df = pd.merge(df, df_pop,on='AreaJP', how='inner')
df.head()
# Out:
#    Postcode AreaJP       Pref     Borough        Area Population
# 0   4710052    逢妻町  AICHI KEN  TOYOTA SHI   AIZUMACHO        684
# 1   4700335    青木町  AICHI KEN  TOYOTA SHI     AOKICHO      4,527
# 2   4710873    秋葉町  AICHI KEN  TOYOTA SHI    AKIBACHO      1,906
# 3   4710835     曙町  AICHI KEN  TOYOTA SHI  AKEBONOCHO      1,055
# 4   4442832    浅谷町  AICHI KEN  TOYOTA SHI   AZAKAICHO        157

# %% [markdown]
# ### Geographical data download

# %%
lat_long = []

def geo(zip_code, API_URL):
    zip = str(zip_code)
    response = urllib.request.urlopen(API_URL + zip)
    xml_result = response.read()
    response.close()
    elem = xml.etree.ElementTree.fromstring(xml_result)
    long = elem.findtext(".//x")
    lat = elem.findtext(".//y")
    data = [zip_code, lat, long]
    return data

URL = 'http://geoapi.heartrails.com/api/xml?method=searchByPostal&postal='

for i in range(len(df)):
    lat_long.append(geo(df.Postcode[i], URL))

df_lat_long = pd.DataFrame(lat_long, columns=['Postcode', 'Latitude', 'Longitude'])  
df_lat_long.head()
# Out:
#    Postcode   Latitude   Longitude
# 0   4710052  35.104364  137.139678
# 1   4700335  35.123342  137.185037
# 2   4710873  35.063098  137.165974
# 3   4710835   35.05884  137.133589
# 4   4442832  35.244875  137.372781

# %%
df = pd.merge(df, df_lat_long, on='Postcode')
df.head()
# Out:
#    Postcode AreaJP       Pref     Borough        Area Population   Latitude  \
# 0   4710052    逢妻町  AICHI KEN  TOYOTA SHI   AIZUMACHO        684  35.104364
# 1   4700335    青木町  AICHI KEN  TOYOTA SHI     AOKICHO      4,527  35.123342
# 2   4710873    秋葉町  AICHI KEN  TOYOTA SHI    AKIBACHO      1,906  35.063098
# 3   4710835     曙町  AICHI KEN  TOYOTA SHI  AKEBONOCHO      1,055   35.05884
# 4   4442832    浅谷町  AICHI KEN  TOYOTA SHI   AZAKAICHO        157  35.244875
#
#     Longitude
# 0  137.139678
# 1  137.185037
# 2  137.165974
# 3  137.133589
# 4  137.372781

# %%
df = df[['Postcode', 'Area', 'Population', 'Latitude', 'Longitude']]
df.head()
# Out:
#    Postcode        Area Population   Latitude   Longitude
# 0   4710052   AIZUMACHO        684  35.104364  137.139678
# 1   4700335     AOKICHO      4,527  35.123342  137.185037
# 2   4710873    AKIBACHO      1,906  35.063098  137.165974
# 3   4710835  AKEBONOCHO      1,055   35.05884  137.133589
# 4   4442832   AZAKAICHO        157  35.244875  137.372781

# %% [markdown]
# ### Foursquare API

# %%
#Input ID, Secret, version, limit, query and radius
CLIENT_ID = 'GB5DHGBTKCEPOJYYHS0C3RZXUUDAI5'# your Foursquare ID
CLIENT_SECRET = 'R5K5ZLHVKAKYIISG' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
query_list = ['食事', 'レストラン', '飲食', '料理', 'パスタ', 'カフェ', 'フード']
radius = 25000
res_info = []

# %%
latitude = df.Latitude[44]
longitude = df.Longitude[44]

query_test = query_list[1]
#set URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, query_test, radius, LIMIT)
    
#get results
results = requests.get(url).json()["response"]['venues']

#print(len(results))
for i in range(len(results)):
    name = results[i]['name']
    category = results[i]['categories'][0]['name']
    lat = results[i]['location']['lat']
    lng = results[i]['location']['lng']
    info = [name, category, lat, lng]
    res_info.append(info)
    print("{},{},lat:{}lng:{}".format(name, category, lat, lng))
# Out:
# レストラン紅葉,Restaurant,lat:35.16987609863281lng:137.40664672851562
# レストラン東郷 トヨタ店,Restaurant,lat:35.081473lng:137.153612
# カントリーレストラン渓流荘,Japanese Restaurant,lat:35.212674332281324lng:137.42821934436074
# カフェレストラン こうらん亭,Café,lat:35.132159lng:137.312636
# インドレストラン ナンハウス 豊田店,Indian Restaurant,lat:35.04082476137397lng:137.15351379381232
# レストラン岡正,Japanese Restaurant,lat:35.213189lng:137.498761
# レストラン常,Diner,lat:35.13913111240994lng:137.24553850078354
# 豊田市役所 レストランひまわり,Restaurant,lat:35.08342lng:137.156378
# レストラン力石,Diner,lat:35.14061347841035lng:137.2217226595734
# 喫茶レストラン丘,Café,lat:34.95594210631444lng:137.166473865509
# レストラン セレーノ,Restaurant,lat:34.94744463222958lng:137.21707520658447
# つくで田舎レストラン すがもり,Japanese Restaurant,lat:35.0305lng:137.46183
# IKEA長久手 レストラン,Restaurant,lat:35.17537107839381lng:137.07531260446595
# レストラン山河,Japanese Restaurant,lat:35.09364759500565lng:137.57323622703552
# Welcome Nepal Restaurant (ウェルカム ネパール レストラン),Asian Restaurant,lat:35.059215564198325lng:137.13019162416458
# 下山ブルーベリーパーク レストラン,Restaurant,lat:35.020391lng:137.390889
# インド＆ネパールレストラン WELCOME,Indian Restaurant,lat:34.9457080997426lng:137.1624689424292
# レストラン ボナール,Restaurant,lat:35.086628lng:137.157533
# インド・ネパール レストラン ヒマラヤ,Indian Restaurant,lat:34.94078lng:137.15117
# レストランバーLUCE,Restaurant,lat:35.085533lng:137.15552
# DIL インドレストラン,Indian Restaurant,lat:34.90425lng:137.160869
# レストラン ブルージュ,French Restaurant,lat:35.04160974354522lng:137.13689982891083
# フォレスタヒルズ レストラン フォンターナ,French Restaurant,lat:35.04017127828179lng:137.1852597759574
# ドームレストラン キャビン,Restaurant,lat:35.33606lng:137.22328
# タイレストラン タニサラ,Thai Restaurant,lat:35.085093lng:137.154576
# レストラン とうじ,Restaurant,lat:35.185169lng:137.09799
# レストランヴェルデロッソ,Restaurant,lat:35.084150924934775lng:137.16967135572173
# 割烹 和風レストラン かわい,Japanese Restaurant,lat:35.36869821091633lng:137.4345562493684
# フォレスタヒルズ レストラン和食 花乃里,Restaurant,lat:35.04043lng:137.185666
# 山のレストラン ふるさと,Café,lat:35.179578lng:137.682523
# カフェレストランEL SUR,Café,lat:35.02175521850586lng:137.17401123046875
# 森のレストラン,Snack Place,lat:35.17392092929989lng:137.0891994787394
# ハンバーグレストラン キッチンフォレスト,Restaurant,lat:35.046371lng:137.140905
# ほがらか T-FACE店,Japanese Restaurant,lat:35.08736123597804lng:137.15483508236815
# Log House,Chinese Restaurant,lat:35.13002626711787lng:137.15940356254578
# 岡崎市役所 レストラン,Restaurant,lat:34.954163lng:137.173855
# レストラン ミヤタ,French Restaurant,lat:34.917774680392256lng:137.18196357123608
# 焼肉レストラン 生弘園,BBQ Joint,lat:34.976224448120135lng:137.1596625899969
# 和レストラン 吉野,Japanese Restaurant,lat:34.972605lng:137.158401
# カフェレストラン ノワール,Café,lat:35.195664lng:137.061178
# スカイレストラン・パリ,Restaurant,lat:34.9558lng:137.16127
# イタリアンレストラン  チェスティーノ,Italian Restaurant,lat:34.90479832396306lng:137.49629522847763
# 農家レストラン mogmog,Restaurant,lat:34.881089lng:137.174605
# 中華レストラン 地久,Beijing Restaurant,lat:34.961265lng:137.140402
# 味蔵,Diner,lat:34.92401797366708lng:137.50704511152296
# インド・ネパールレストランヒマラヤ,Indian Restaurant,lat:34.940767lng:137.151052

# %% [markdown]
# ## 4) Methodology<a name="Methodology"></a>

# %% [markdown]
# In this project I will search areas of Toyota city with low restaurant density and higher population density.
# As a first step I will get the restaurant information including location and category the post codes of each region in Toyota.
# Then plot the restaurant location in the map to visualize the current situation.
# Next I will calculate ratio of population vs restaurant number for each post codes.
# Finally I will summarize better places for new restaurant from the visual data.

# %% [markdown]
# ### Restaurant data correction

# %%
#Due to the limitation of API I determined geographic center.
latitude = df.Latitude[44]
longitude = df.Longitude[44]
    
for query in query_list:
    
#set URL
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, query, radius, LIMIT)
    
#get results
    results = requests.get(url).json()["response"]['venues']
        
        
#print(len(results))
    for i in range(len(results)):
        name = results[i]['name']
        category = results[i]['categories'][0]['name']
        lat = results[i]['location']['lat']
        lng = results[i]['location']['lng']
        info = [name, category, lat, lng]
        res_info.append(info)
    #print("{},{},lat:{}lng:{}".format(name, category, lat, lng))

# %%
dname = ["name", "category", "Latitude", "Longitude"]
df_res = pd.DataFrame(res_info, columns=dname)
print(len(res_info))
df_res
# Out:
# 182
#                                     name                category   Latitude  \
# 0                               お食事処 花の木              Restaurant  35.155556
# 1                              花もみじ お食事処                   Diner  35.133366
# 2                              お食事処 さつき亭     Japanese Restaurant  35.184585
# 3                             お食事処 どんぐり亭     Japanese Restaurant  35.213617
# 4                                お食事処 舞心     Japanese Restaurant  35.073095
# 5                             お食事処 楽 豊田店                   Diner  35.122085
# 6                               御食事処きらく亭     Japanese Restaurant  35.141777
# 7                              食事処 葵 伊保店              Restaurant  35.124037
# 8                                お食事処 野内     Japanese Restaurant  35.349329
# 9                                食事処 富久屋     Japanese Restaurant  35.258672
# 10                                食事処吉田屋     Japanese Restaurant  35.309570
# 11                             お食事処 かわかみ     Japanese Restaurant  35.304910
# 12                              喫茶御食事処 庵                Tea Room  35.304164
# 13                            御食事処 藤棚 売店                   Diner  34.955045
# 14                                  下山の里          Farmers Market  35.035386
# 15                           喫茶 食事 サンパール              Restaurant  35.095394
# 16                                食事処ナンワ                   Diner  35.149609
# 17                               お食事処 鳥兵     Japanese Restaurant  35.364774
# 18                               食事処 ふる里     Japanese Restaurant  35.364258
# 19                                 お食事処藤     Japanese Restaurant  35.107747
# 20                            食事処 シバタ屋食堂                    Food  35.062674
# 21                                  食事亭葵                   Diner  35.126546
# 22                               食事処 とよね     Japanese Restaurant  35.057080
# 23                               御食事処 山葵     Japanese Restaurant  35.318061
# 24                           食事処　うなぎ　とよね     Japanese Restaurant  35.056335
# 25                              大衆お食事処 平                   Diner  35.027404
# 26                                食事処 はず                   Diner  35.300591
# 27                                お食事処わか     Japanese Restaurant  35.060129
# 28                                喫茶お食事樹                    Café  35.193616
# 29                            鉄板焼＆お食事 永楽                   Diner  35.042436
# ..                                   ...                     ...        ...
# 152                            カフェチャンプール                    Food  35.089298
# 153                                いとカフェ                    Café  35.092204
# 154                             カフェ 山ぼうし                    Café  35.365657
# 155                               カフェダブル                    Café  35.066893
# 156                          星空カフェ「てんくう」                    Café  35.220561
# 157                               カフェことり                    Café  35.219780
# 158                  焼き菓子&カフェ sanc-souci                    Café  35.077415
# 159                    ミールカフェ (Мир Cafe)                    Café  34.910653
# 160                              カフェドシェフ             Coffee Shop  35.091095
# 161                            アイランド・カフェ                    Café  35.352459
# 162                       カフェレストランEL SUR                    Café  35.021755
# 163                              プラチナカフェ                    Café  35.348460
# 164                          カフェヨシノ みよし店                Tea Room  35.107120
# 165                         地産地消カフェ ホガラカ                    Café  35.080989
# 166          Earth Food Cafe (アースフードカフェ)                    Café  34.972973
# 167                          フードショップ ふじや             Supermarket  35.041715
# 168   Maimai Kitchen (まいまいキッチン (フードコート))              Food Court  35.078492
# 169                      ピアゴ 上和田店 フードコート              Food Court  34.933747
# 170                       フィール フードメッセトヨタ             Supermarket  35.063347
# 171                      イオンモール岡崎 フードコート              Food Court  34.938344
# 172                          フードエキスポ 太田屋          Takoyaki Place  35.072853
# 173                       アイ・モール三好フードコート              Food Court  35.093234
# 174                         フードショップ タカハシ           Grocery Store  34.929852
# 175                     スウェディッシュフードマーケット                  Market  35.175894
# 176                         フードコート ピアゴ洞店              Food Court  34.929267
# 177  ファインフードカフェ くるみ (FINE FOOD CAFE くるみ)     Japanese Restaurant  34.926871
# 178        中京大学 豊田キャンパス 19号館 PLAZA LISTA              University  35.139343
# 179                    フード＆ドラッグ ゲンキー 福岡店               Drugstore  34.908512
# 180                 イオンモール岡崎 フードコート横の喫煙所              Smoke Shop  34.938512
# 181                        花門亭 イオンモール岡崎店  Okonomiyaki Restaurant  34.938232
#
#       Longitude
# 0    137.340354
# 1    137.311799
# 2    137.060401
# 3    137.502952
# 4    137.162534
# 5    137.136948
# 6    137.167910
# 7    137.154298
# 8    137.365861
# 9    137.559435
# 10   137.354889
# 11   137.388649
# 12   137.387704
# 13   137.158609
# 14   137.311779
# 15   137.189964
# 16   137.147724
# 17   137.443786
# 18   137.441048
# 19   137.164840
# 20   137.117782
# 21   137.123491
# 22   137.149823
# 23   137.189671
# 24   137.146759
# 25   137.176663
# 26   137.156888
# 27   137.143997
# 28   137.103212
# 29   137.139808
# ..          ...
# 152  137.153641
# 153  137.155608
# 154  137.433799
# 155  137.155259
# 156  137.654295
# 157  137.097484
# 158  137.173965
# 159  137.195888
# 160  137.128649
# 161  137.393810
# 162  137.174011
# 163  137.331199
# 164  137.097120
# 165  137.158263
# 166  137.156221
# 167  137.320034
# 168  137.159723
# 169  137.148036
# 170  137.162011
# 171  137.165328
# 172  137.150450
# 173  137.078449
# 174  137.216518
# 175  137.074936
# 176  137.181004
# 177  137.160063
# 178  137.147765
# 179  137.152440
# 180  137.165091
# 181  137.165476
#
# [182 rows x 4 columns]

# %% [markdown]
# ### Data visualization

# %%
import numpy as np
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium

# %%
address  =  'Toyota'
geolocator = Nominatim(user_agent="Toyota_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

Toyota_map = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, name, category in zip(df_res['Latitude'], df_res['Longitude'], df_res['name'], df_res['category']):
    label = '{}, {}'.format(name, category)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Toyota_map)
    
Toyota_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Analysis of visual data

# %% [markdown]
# As shown in the map almost all the restaurant is in urban area of the Toyota city.
# My assumption on the reason of this distribution is among mountains(green colored) lower population density
# resulting in the difficulty in attracting customers to restaurants.
# To confirm this assumption, I plot the population of each area in the bubble charts.

# %%
import math

address  =  'Toyota'
geolocator = Nominatim(user_agent="Toyota_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

Toyota_map = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, name, category in zip(df_res['Latitude'], df_res['Longitude'], df_res['name'], df_res['category']):
    label = '{}, {}'.format(name, category)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Toyota_map)

for lat, lng, population, postcode, area in zip(df['Latitude'], df['Longitude'], df['Population'], df['Postcode'], df['Area']):
    population=math.ceil(float(population.replace(",", ""))/150)
    if population == 0:
        break
    else:
        #print(population)
        label = '{}, {}'.format(postcode, area)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=population,
            popup=label,
            color='red',
            fill=True,
            fill_color='pink',
            fill_opacity=0.7,
            parse_html=False).add_to(Toyota_map)

    
Toyota_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As expected, most of people are living in central Toyota-city.
# However there are three big circles can be seen in moutain are.
# These area has relatively higher population density and not so much restaurant.
# So I will focus on these 3 areas.
# To judge which one is the best place for new restaurant, I should set the criteria.
# For this I set the ratio of population vs restaurant in urban area of Toyota-city as the criteria value.
# First I create the linear Regression model of restaurant number vs population to estimate the affordable number of restaurant.
# Then using this model to estimate the gap between ideal resutaurant number and actual number.
# Finally determine the best area to open the restaurants among the three areas.

# %% [markdown]
# ### Data preporcessing to create the regression model

# %%
df['Population'] = df['Population'].str.replace(',','')
df['Population'] = df['Population'].astype(int)
df.head()
# Out:
#    Postcode        Area  Population   Latitude   Longitude
# 0   4710052   AIZUMACHO         684  35.104364  137.139678
# 1   4700335     AOKICHO        4527  35.123342  137.185037
# 2   4710873    AKIBACHO        1906  35.063098  137.165974
# 3   4710835  AKEBONOCHO        1055   35.05884  137.133589
# 4   4442832   AZAKAICHO         157  35.244875  137.372781

# %%
#Extract urban area by population filtering.
df_ooi = df[df['Population'] > 2000].reset_index()
df_ooi = df_ooi[['Postcode', 'Area', 'Population', 'Latitude', 'Longitude']]
print(len(df_ooi))
df_ooi.head()
# Out:
# 62
#    Postcode          Area  Population   Latitude   Longitude
# 0   4700335       AOKICHO        4527  35.123342  137.185037
# 1   4710858    ASAHIGAOKA        2560  35.079668  137.142553
# 2   4710031    ASAHIMACHI        3759  35.092834  137.140076
# 3   4710006     ICHIGICHO        5352  35.095561  137.195215
# 4   4710814  ITSUTSUGAOKA        6204  35.066017  137.196499

# %%
#Visualization
address  =  'Toyota'
geolocator = Nominatim(user_agent="Toyota_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

Toyota_map = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, population, postcode, area in zip(df_ooi['Latitude'], df_ooi['Longitude'], df_ooi['Population'], df_ooi['Postcode'], df_ooi['Area']):
    population=population/150
    if population == 0:
        break
    else:
        #print(population)
        label = '{}, {}'.format(postcode, area)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=population,
            popup=label,
            color='red',
            fill=True,
            fill_color='pink',
            fill_opacity=0.7,
            parse_html=False).add_to(Toyota_map)

    
Toyota_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Get the number of restaurans from Foursquare API.
CLIENT_ID = 'IEKXI2FEFBC5CWDKKP0UM2NVOH5FPX2UUBS'# your Foursquare ID
CLIENT_SECRET = 'YN3SPY1AO11JMHMJRCHW' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
query_list = ['食事', 'レストラン', '飲食', '料理', 'パスタ', 'カフェ', 'フード']
radius = 5000
num_of_res = []
res_num = 0

# %%
for i in range(len(df_ooi)):
    latitude = df_ooi.Latitude[i]
    longitude = df_ooi.Longitude[i]

    for query in query_list:
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, query, radius, LIMIT)
        results = requests.get(url).json()["response"]['venues']
        
        if len(results) == 0:
            break
        else:
            res_num = res_num + len(results)

    num_of_res.append(res_num)
    res_num = 0
    #print(num_of_res)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-164-c67b6b26bfd1> in <module>
#       5     for query in query_list:
#       6         url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, query, radius, LIMIT)
# ----> 7         results = requests.get(url).json()["response"]['venues']
#       8
#       9         if len(results) == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df_ooi['ResNum'] = pd.DataFrame(num_of_res)
df_ooi.head(62)
